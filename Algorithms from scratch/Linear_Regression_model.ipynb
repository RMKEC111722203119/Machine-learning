# %% [markdown]
# <a href="https://colab.research.google.com/github/RMKEC111722203119/Machine-learning/blob/main/Linear_Regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression ***model***

# %% [markdown]
# **Y=wx+b**
#
# x is array therefore,
#
# x.dot(self.w)+self.b

# %% [markdown]
# # Gradient Descent
#
# optimisation algo to find the minimal Loss function
#
# w = w - a*dw
#
# b = b - b*db
#
#
#
#
#
#
# where, a is the learning rate
#
# used for updating parameters
#
# ![Gradient.png](data:image/png;base64,...)

# %% [markdown]
# # Learning Rate
# Step size of iteration
#
#  ![learnig.png](data:image/png;base64,...)
#
#  ![gradient descendent.png](data:image/png;base64,...)

# %% [markdown]
# # Implementation of model

# %%
import numpy as np

# %%
class Linear_Regression():

  def __init__(self,Learning_rate,no_of_iterations):

    self.Learning_rate=Learning_rate
    self.no_of_iterations=no_of_iterations


  def fit(self,X,Y):

    self.m,self.n=X.shape  #n=no of features,m=training sets

    self.w= np.zeroes(self.n)
    self.b= 0
    self.X=X
    self.Y=Y

    for i in range (self.no_of_iterations): #implementation of gradient descendant
      self.update_weights( )



  def update_weights(self,):

    Y_prediction = self.predict(self.X)

    dw= -(2*(self.X.T).dot(self.Y-Y_prediction)) /self.m  #learning rate formula

    db= -(2*np.sum(self.Y-Y_prediction))/self.m

    w= self.w-self.Learning_rate*dw #gradient descendant formula

    b= self.b-self.Learning_rate*db



  def predict(self,X):

    return X.dot(self.w)+self.b # y=wx+b
